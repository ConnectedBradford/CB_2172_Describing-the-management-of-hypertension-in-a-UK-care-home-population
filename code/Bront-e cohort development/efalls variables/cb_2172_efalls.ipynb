# %%
#table for the 36 predictor variables for efalls to calculate efalls for the care home cohort at point of admission
create or replace table `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls` as (
with master as 
(select
person_id, age_admission, gender_source_value as gender
from `yhcr-prd-phm-bia-core.CB_2172.temp_cb_2172_ch_cohort_demographic`),

al as 
(select
person_id,
activity_limitation
from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_al`),

alc as 
(select
person_id, alcohol_status
from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_alcohol_current_status` 
),
prev_alc as 
(select
person_id, alcohol_status
from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_pev_alc_harm` ),

af as (
  select
  person_id, atrial_fibrillation
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_af`   
),
abdo as (
  select 
  person_id, abdominal_pain from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_abdo`
),
anaemia as (
  select
  person_id,case when diagnosis_date is not null and anaemia_resolved is null then 'true' end as anaemia_diagnosis from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_anaemia`
),
asth as (
  select
  person_id,asthma from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_asthma`
  
),
bp as (
  select
  person_id, back_pain from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_back_pain`
),
bmi as (
  select
  person_id,bmi_factor
  from `yhcr-prd-phm-bia-core.CB_2172.temp_cb_2172_efi2_bmi`),
bd as (
  select
  person_id,bone_disease from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_bd`
),
ca as (
  select
  person_id, cancer_diagnosis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_cancer_diagnosis`
),

ci as (
  select
  person_id, cognitive_impairement
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_ci`
),

co as (
  select
  person_id,copd
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_copd`
),
dp as (
  select
  person_id, depression from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_depression`
),
dm as (
  select
  person_id, 
  dementia
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_dementia`
),
t2dm as (
  select
  person_id,
  diabetes_mellitus from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_diabetes_mellitus`
),
dz as (
  select dizziness, person_id from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_dizziness`
),
dress as (
  select
  person_id,
  dress_diagnosis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_dress_diagnosis`
),
enviro as (
  select
  person_id,
  environment_problem
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_environment`
),
fall as (
  select
  person_id,
  fall
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_fall`
),
fat as (
  select
  person_id, 
  fatigue
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_fatigue`
),
fi as (
  select
person_id, faecal_incontinence
from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_fi`
),
foot as (
  select
  person_id, fatigue as foot
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_foot_problem`
),
fracture as (
  select
  person_id,
  fracture
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_fracture`),
frag_fracture as (
  select
 person_id,
 frag_fracture_diagnosis
 from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_fragfracture`
),
gmh as (
  select 
  person_id, mental_health
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_mh`
),
hb as (
  select
  person_id,
  hb_diagnosis,
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_hb`
),
head as (
  select
  person_id,headache
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_headache`
),
hf as (
  select
  person_id,
  heart_failure
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_hf`
),
hi as (
  select
  person_id,hearing_impairment
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_hearing_impairment`
),
hypotension as (
  select
  person_id,
  hypotension_diagnosis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_hypotension_union`
),
htn as (
  select
  person_id, hypertension_diagnosis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_hypertension_union`
),
ia as (
  select
  person_id,inflammatory_arthritis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_inflammatory_arthirtis`
),
i_b_d as (
  select 
  person_id, ibd as inflammatory_bowel_disease from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_ibd`
),
liver_problem as (
  select
  person_id, 
  liver_problem
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_liver`),
meds as (
  select
  person_id, 
  meds_management
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_meds_management`),
memory as (
  select
  person_id,memory_concern
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_memory_concern`
),
mp as (
  select person_id,meal_problem
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_mp`
),
mobility as (
  select
  person_id,mobility_problem
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_mobility`
),
mono as (
  select person_id, paresis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_paresis`
),
mnd as (
  select
  person_id,mnd
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_mnd`
),
musclo as (
  select
  person_id,msk
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_msk`
),
oa as (
  select
  person_id, osteoarthritis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_osteoarthritis`
),
op as (
  select 
  person_id,osteoporosis
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_osteoporosis`
),
weight as (
  select
  person_id, bmi_factor
  from 
  `yhcr-prd-phm-bia-core.CB_2172.temp_cb_2172_efi2_bmi`
),
pp as (
  select
  person_id,
  no_medication,
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_polypharmacy`
),
pc as (
  select
  person_id, 
  palliative_care
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_palliative`
),
pnd as (
  select
  person_id, peripheral_neuropathy
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_peripheral_neuropathy`
),
pt as (
  select
  person_id,parkinsonism_tremor
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_pt` 
),
pud as (
  select
  person_id, peptic_ulcer_disease
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_pud`
),
pvd as (
  select
  person_id, peripheral_vascular_disease from
  `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_pvd`
),
rc as (
  select
  person_id, requirement_care
  from 
  `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_require_care`
),
rd as (
  select person_id,
  respiratory_disease
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_resp_disease`
),
sp as (
  select
  person_id, sleep_problem
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_sleep_problem`
),
seiz as (
  select
  person_id, seizure
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_seizure`
),
sh as 
(select person_id, self_harm
from `yhcr-prd-phm-bia-core.CB_2172.temp_cb_2172_efi2_self_harm`),
su as (
  select person_id, skin_ulcer 
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_skin_ulcer`
),
smoke as (
  select person_id, smoking_status
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_smoking_status`
),
sv as (
  select
  person_id, social_vulnerability
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_sv`
),
st as(
  select
  person_id, stress
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_stress`
),
smh as (
  select
  person_id,severe_mental
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_severe_mental`
),
cere as (
  select
  person_id,stroke
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_stroke`
),
tia_cte as (
  select
  person_id, tia
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_tia`
),
thy as(
  select
  person_id, thyroid_problem
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_thyroid`
),
ui as (
  select
  person_id, urinary_incontinence
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_urinary_incontinence`
),
ud as (
  select
  person_id, urinary_disease
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_urinary_disease`
),
vi as (
  select 
  person_id, visual_impairment
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_vi`
),
wb as (
  select
  person_id, washing_bathing
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_washing_bathing`
),
wk as (
  select person_id, weakness
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efalls_weakness`
),
wl as (
  select
  person_id, 
  weight_loss
  from `yhcr-prd-phm-bia-core.CB_2172.cb_2172_efi2_wl`
)

SELECT
master.person_id, 
master.age_admission,
master.gender,
al.activity_limitation,
alc.alcohol_status,
prev_alc.alcohol_status as previous_harm_alcohol,
atrial_fibrillation,
abdominal_pain,
anaemia_diagnosis,
asthma,
bone_disease,
bmi.bmi_factor,
back_pain,
cancer_diagnosis,
cognitive_impairement,
COPD,
dementia,
depression,
dress_diagnosis,
diabetes_mellitus,
dizziness,
environment_problem,
fall.fall,
faecal_incontinence,
fat.fatigue,
foot,
fracture.fracture,
frag_fracture_diagnosis,
hb_diagnosis,
heart_failure,
hearing_impairment,
headache,
hypotension_diagnosis,
hypertension_diagnosis,
liver_problem.liver_problem,
i_b_d.inflammatory_bowel_disease,
inflammatory_arthritis,
meds_management,
mental_health,
memory_concern,
mobility_problem,
mnd.mnd,
meal_problem,
msk,
no_medication,
paresis,
osteoarthritis,
osteoporosis,
palliative_care,
parkinsonism_tremor,
peptic_ulcer_disease,
peripheral_vascular_disease,
peripheral_neuropathy,
respiratory_disease,
requirement_care,
seizure,
self_harm,
severe_mental,
skin_ulcer,
sleep_problem,
smoking_status,
social_vulnerability,
stroke,
stress,
thyroid_problem,
urinary_incontinence,
urinary_disease,
visual_impairment,
washing_bathing,
weakness,
weight_loss
from master 
left join abdo on
master.person_id = abdo.person_id
left join al on
master.person_id = al.person_id 
left join alc on
master.person_id = alc.person_id
left join prev_alc on
master.person_id = prev_alc.person_id
left join af on
master.person_id = af.person_id
left join anaemia on 
master.person_id = anaemia.person_id
left join asth on 
master.person_id = asth.person_id
left join bmi on
master.person_id = bmi.person_id
left join bd on
master.person_id = bd.person_id
left join bp on 
master.person_id = bp.person_id
left join ca on 
master.person_id = ca.person_id
left join ci on 
master.person_id = ci.person_id
left join co on 
master.person_id = co.person_id
left join dp on
master.person_id = dp.person_id
left join dm on
master.person_id = dm.person_id
left join dz on 
master.person_id = dz.person_id
left join t2dm on
master.person_id = t2dm.person_id
left join dress on
master.person_id = dress.person_id
left join enviro on 
master.person_id = enviro.person_id
left join fall on 
master.person_id = fall.person_id
left join fat on 
master.person_id = fat.person_id
left join fi on
master.person_id = fi.person_id
left join foot on 
master.person_id = foot.person_id
left join fracture on
master.person_id = fracture.person_id
left join frag_fracture on
master.person_id = frag_fracture.person_id
left join hb on 
master.person_id = hb.person_id
left join head on
master.person_id = head.person_id
left join hf on
master.person_id = hf.person_id
left join hi on
master.person_id = hi.person_id
left join htn on
master.person_id = htn.person_id
left join hypotension on
master.person_id = hypotension.person_id
left join gmh on
master.person_id = gmh.person_id
left join liver_problem on
master.person_id = liver_problem.person_id
left join ia on
master.person_id = ia.person_id
left join i_b_d on 
master.person_id = i_b_d.person_id
left join meds on 
master.person_id = meds.person_id
left join memory on
master.person_id = memory.person_id
left join mobility on 
master.person_id = mobility.person_id
left join mnd on 
master.person_id = mnd.person_id
left join mp on
master.person_id = mp.person_id
left join mono on 
master.person_id = mono.person_id
left join musclo on 
master.person_id = musclo.person_id
left join oa on 
master.person_id = oa.person_id
left join op on 
master.person_id = op.person_id
left join pp on
master.person_id = pp.person_id
left join pc on
master.person_id = pc.person_id
left join pt on 
master.person_id = pt.person_id
left join pud on
master.person_id = pud.person_id
left join pnd on
master.person_id = pnd.person_id
left join pvd on 
master.person_id = pvd.person_id
left join rc on
master.person_id = rc.person_id
left join rd on
master.person_id = rd.person_id
left join seiz on
master.person_id = seiz.person_id
left join smh on
master.person_id = smh.person_id
left join sh on 
master.person_id = sh.person_id
left join st on 
master.person_id = st.person_id
left join su on 
master.person_id = su.person_id
left join smoke on
master.person_id = smoke.person_id
left join sv on 
master.person_id = sv.person_id
left join sp on
master.person_id = sp.person_id
left join cere on
master.person_id = cere.person_id
left join tia_cte on
master.person_id = tia_cte.person_id
left join thy on
master.person_id = thy.person_id
left join ui on
master.person_id = ui.person_id
left join ud on
master.person_id = ud.person_id
left join vi on 
master.person_id = vi.person_id
left join wb on
master.person_id = wb.person_id 
left join wk on 
master.person_id = wk.person_id
left join wl on
master.person_id = wl.person_id)
